# %%
import pandas as ps
from slugify import slugify

# %% [markdown]
# # Importar Dados de Títulos do IMDB

# %%
df_imdb_titles = ps.read_csv('./data/title.basics.tsv', 
                             sep='\t', 
                             na_values='\\N', 
                             encoding='utf8', 
                             dtype=str)
df_imdb_titles.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     movie                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle isAdult startYear endYear  \
# 0                                   Carmencita       0      1894     NaN
# 1                       Le clown et ses chiens       0      1892     NaN
# 2                               Pauvre Pierrot       0      1892     NaN
# 3                                  Un bon bock       0      1892     NaN
# 4                             Blacksmith Scene       0      1893     NaN
# 5                            Chinese Opium Den       0      1894     NaN
# 6  Corbett and Courtney Before the Kinetograph       0      1894     NaN
# 7       Edison Kinetoscopic Record of a Sneeze       0      1894     NaN
# 8                                   Miss Jerry       0      1894     NaN
# 9          La sortie de l'usine Lumière à Lyon       0      1895     NaN
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              5  Animation,Comedy,Romance
# 3             12           Animation,Short
# 4              1              Comedy,Short
# 5              1                     Short
# 6              1               Short,Sport
# 7              1         Documentary,Short
# 8             45                   Romance
# 9              1         Documentary,Short

# %% [markdown]
# ## Filtrar apenas filmes e séries

# %%
types = df_imdb_titles['titleType'].unique()
types
df_imdb_titles = df_imdb_titles[df_imdb_titles['titleType'].isin(['movie', 'tvSeries'])]

# %% [markdown]
# ## Converter dados
# - `startYear` de float para inteiro
# - `endYear` de float para inteiro
# - `isAdult` de float para booleano

# %%
df_imdb_titles['startYear'] = ps.to_numeric(df_imdb_titles['startYear'], errors='coerce', downcast='integer')
df_imdb_titles['endYear'] = ps.to_numeric(df_imdb_titles['endYear'], errors='coerce', downcast='integer')
df_imdb_titles['isAdult'] = df_imdb_titles['isAdult'].apply(lambda x: False if x == 0 else True)
df_imdb_titles['primaryTitle'] = df_imdb_titles['primaryTitle'].astype(str)

# %% [markdown]
# ## Criar slug do título

# %%
df_imdb_titles.dtypes
df_imdb_titles['primaryTitleSlug'] = df_imdb_titles['primaryTitle'].fillna('').apply(lambda x: slugify(str(x)))

# %% [markdown]
# ## Criar slug dos gêneros

# %%
df_imdb_titles['genres'] = df_imdb_titles['genres'].fillna('').str.split(',').apply(lambda x:[slugify(value) for value in x])

# %%
df_imdb_titles.head(10)
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 498  tt0000502     movie                        Bohemios
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 610  tt0000615     movie              Robbery Under Arms
# 625  tt0000630     movie                          Hamlet
# 668  tt0000675     movie                     Don Quijote
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
# 828  tt0000838     movie              A Cultura do Cacau
#
#                       originalTitle  isAdult  startYear  endYear  \
# 8                        Miss Jerry     True     1894.0      NaN
# 144   The Corbett-Fitzsimmons Fight     True     1897.0      NaN
# 498                        Bohemios     True     1905.0      NaN
# 570     The Story of the Kelly Gang     True     1906.0      NaN
# 587               L'enfant prodigue     True     1907.0      NaN
# 610              Robbery Under Arms     True     1907.0      NaN
# 625                          Amleto     True     1908.0      NaN
# 668                     Don Quijote     True     1908.0      NaN
# 672  The Fairylogue and Radio-Plays     True     1908.0      NaN
# 828              A Cultura do Cacau     True     1909.0      NaN
#
#     runtimeMinutes                          genres  \
# 8               45                       [romance]
# 144            100      [documentary, news, sport]
# 498            100                              []
# 570             70  [action, adventure, biography]
# 587             90                         [drama]
# 610            NaN                         [drama]
# 625            NaN                         [drama]
# 668            NaN                         [drama]
# 672            120            [adventure, fantasy]
# 828            NaN                              []
#
#                    primaryTitleSlug
# 8                        miss-jerry
# 144   the-corbett-fitzsimmons-fight
# 498                        bohemios
# 570     the-story-of-the-kelly-gang
# 587                the-prodigal-son
# 610              robbery-under-arms
# 625                          hamlet
# 668                     don-quijote
# 672  the-fairylogue-and-radio-plays
# 828              a-cultura-do-cacau

# %% [markdown]
# ## Normalizar tipo

# %%
df_imdb_titles['titleType'] = df_imdb_titles['titleType'].fillna('').apply(lambda x: slugify(str(x)))
df_imdb_titles.head(10)
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 498  tt0000502     movie                        Bohemios
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 610  tt0000615     movie              Robbery Under Arms
# 625  tt0000630     movie                          Hamlet
# 668  tt0000675     movie                     Don Quijote
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
# 828  tt0000838     movie              A Cultura do Cacau
#
#                       originalTitle  isAdult  startYear  endYear  \
# 8                        Miss Jerry     True     1894.0      NaN
# 144   The Corbett-Fitzsimmons Fight     True     1897.0      NaN
# 498                        Bohemios     True     1905.0      NaN
# 570     The Story of the Kelly Gang     True     1906.0      NaN
# 587               L'enfant prodigue     True     1907.0      NaN
# 610              Robbery Under Arms     True     1907.0      NaN
# 625                          Amleto     True     1908.0      NaN
# 668                     Don Quijote     True     1908.0      NaN
# 672  The Fairylogue and Radio-Plays     True     1908.0      NaN
# 828              A Cultura do Cacau     True     1909.0      NaN
#
#     runtimeMinutes                          genres  \
# 8               45                       [romance]
# 144            100      [documentary, news, sport]
# 498            100                              []
# 570             70  [action, adventure, biography]
# 587             90                         [drama]
# 610            NaN                         [drama]
# 625            NaN                         [drama]
# 668            NaN                         [drama]
# 672            120            [adventure, fantasy]
# 828            NaN                              []
#
#                    primaryTitleSlug
# 8                        miss-jerry
# 144   the-corbett-fitzsimmons-fight
# 498                        bohemios
# 570     the-story-of-the-kelly-gang
# 587                the-prodigal-son
# 610              robbery-under-arms
# 625                          hamlet
# 668                     don-quijote
# 672  the-fairylogue-and-radio-plays
# 828              a-cultura-do-cacau

# %% [markdown]
# ## Renomear colunas

# %%
df_imdb_titles.rename(
    {'tconst': 'imdb_id', 'titleType': 'type', 'primaryTitle': 'primary_title', 'originalTitle': 'original_title', 'isAdult': 'is_adult', 'startYear': 'start_year', 'endYear': 'end_year', 'runtimeMinutes': 'runtime_minutes', 'primaryTitleSlug': 'title_slug'},
    axis=1,
    inplace=True)
df_imdb_titles.head(10)
# Out:
#        imdb_id   type                   primary_title  \
# 8    tt0000009  movie                      Miss Jerry
# 144  tt0000147  movie   The Corbett-Fitzsimmons Fight
# 498  tt0000502  movie                        Bohemios
# 570  tt0000574  movie     The Story of the Kelly Gang
# 587  tt0000591  movie                The Prodigal Son
# 610  tt0000615  movie              Robbery Under Arms
# 625  tt0000630  movie                          Hamlet
# 668  tt0000675  movie                     Don Quijote
# 672  tt0000679  movie  The Fairylogue and Radio-Plays
# 828  tt0000838  movie              A Cultura do Cacau
#
#                      original_title  is_adult  start_year  end_year  \
# 8                        Miss Jerry      True      1894.0       NaN
# 144   The Corbett-Fitzsimmons Fight      True      1897.0       NaN
# 498                        Bohemios      True      1905.0       NaN
# 570     The Story of the Kelly Gang      True      1906.0       NaN
# 587               L'enfant prodigue      True      1907.0       NaN
# 610              Robbery Under Arms      True      1907.0       NaN
# 625                          Amleto      True      1908.0       NaN
# 668                     Don Quijote      True      1908.0       NaN
# 672  The Fairylogue and Radio-Plays      True      1908.0       NaN
# 828              A Cultura do Cacau      True      1909.0       NaN
#
#     runtime_minutes                          genres  \
# 8                45                       [romance]
# 144             100      [documentary, news, sport]
# 498             100                              []
# 570              70  [action, adventure, biography]
# 587              90                         [drama]
# 610             NaN                         [drama]
# 625             NaN                         [drama]
# 668             NaN                         [drama]
# 672             120            [adventure, fantasy]
# 828             NaN                              []
#
#                          title_slug
# 8                        miss-jerry
# 144   the-corbett-fitzsimmons-fight
# 498                        bohemios
# 570     the-story-of-the-kelly-gang
# 587                the-prodigal-son
# 610              robbery-under-arms
# 625                          hamlet
# 668                     don-quijote
# 672  the-fairylogue-and-radio-plays
# 828              a-cultura-do-cacau

# %% [markdown]
# ## Dicionário do DataFrame
#
# |Coluna|Tipo|Descrição|
# |--|--|--|
# | id | string | alphanumeric unique identifier of the title. |
# | title_type | string | the type/format of the title (e.g. movie, short,tvseries, tvepisode, video, etc). |
# | primary_title | string | the more popular title / the title used by the filmmakers on promotional materials at the point of release. |
# | original_title | string | original title, in the original language. |
# | is_adult | boolean | 0: non-adult title; 1: adult title. |
# | start_year | int | represents the release year of a title. In the case of TV Series, it is the series start year. |
# | end_year | int | TV Series end year. for all other title types. |
# | runtime_minutes | – | primary runtime of the title, in minutes. |
# | genres | string array | includes up to three genres associated with the title. |
# | title_slug | string | title slug

# %% [markdown]
# # Importar Dados de Notas do IMDB

# %%
df_imdb_title_ratings = ps.read_csv('./data/title.ratings.tsv', 
                             sep='\t', 
                             na_values='\\N', 
                             encoding='utf8', 
                             dtype=str)
df_imdb_title_ratings.head(10)
# Out:
#       tconst averageRating numVotes
# 0  tt0000001           5.7     2045
# 1  tt0000002           5.7      273
# 2  tt0000003           6.5     2003
# 3  tt0000004           5.4      178
# 4  tt0000005           6.2     2763
# 5  tt0000006           5.0      183
# 6  tt0000007           5.4      855
# 7  tt0000008           5.4     2189
# 8  tt0000009           5.3      210
# 9  tt0000010           6.8     7542

# %% [markdown]
# ## Converter Dados
# - `averageRating` para float
# - `numVotes` para int

# %%
df_imdb_title_ratings['tconst'] = df_imdb_title_ratings['tconst'].astype(str)
df_imdb_title_ratings['averageRating'] = df_imdb_title_ratings['averageRating'].astype(float)
df_imdb_title_ratings['numVotes'] = df_imdb_title_ratings['numVotes'].astype(int)
df_imdb_title_ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %% [markdown]
# ## Renomar colunas

# %%
df_imdb_title_ratings.rename(
    {'tconst': 'imdb_id', 'averageRating': 'average_rating', 'numVotes': 'num_votes'},
    axis=1,
    inplace=True)
df_imdb_title_ratings.head(10)
# Out:
#      imdb_id  average_rating  num_votes
# 0  tt0000001             5.7       2045
# 1  tt0000002             5.7        273
# 2  tt0000003             6.5       2003
# 3  tt0000004             5.4        178
# 4  tt0000005             6.2       2763
# 5  tt0000006             5.0        183
# 6  tt0000007             5.4        855
# 7  tt0000008             5.4       2189
# 8  tt0000009             5.3        210
# 9  tt0000010             6.8       7542

# %% [markdown]
# # Combinando Dados de Filmes e Notas do IMDB

# %%
df_imdb = ps.merge(left=df_imdb_titles, right=df_imdb_title_ratings, how='inner', on='imdb_id')
df_imdb.head(10)
# Out:
#      imdb_id   type                   primary_title  \
# 0  tt0000009  movie                      Miss Jerry
# 1  tt0000147  movie   The Corbett-Fitzsimmons Fight
# 2  tt0000502  movie                        Bohemios
# 3  tt0000574  movie     The Story of the Kelly Gang
# 4  tt0000591  movie                The Prodigal Son
# 5  tt0000615  movie              Robbery Under Arms
# 6  tt0000630  movie                          Hamlet
# 7  tt0000675  movie                     Don Quijote
# 8  tt0000679  movie  The Fairylogue and Radio-Plays
# 9  tt0000862  movie                      Faldgruben
#
#                    original_title  is_adult  start_year  end_year  \
# 0                      Miss Jerry      True      1894.0       NaN
# 1   The Corbett-Fitzsimmons Fight      True      1897.0       NaN
# 2                        Bohemios      True      1905.0       NaN
# 3     The Story of the Kelly Gang      True      1906.0       NaN
# 4               L'enfant prodigue      True      1907.0       NaN
# 5              Robbery Under Arms      True      1907.0       NaN
# 6                          Amleto      True      1908.0       NaN
# 7                     Don Quijote      True      1908.0       NaN
# 8  The Fairylogue and Radio-Plays      True      1908.0       NaN
# 9                      Faldgruben      True      1909.0       NaN
#
#   runtime_minutes                          genres  \
# 0              45                       [romance]
# 1             100      [documentary, news, sport]
# 2             100                              []
# 3              70  [action, adventure, biography]
# 4              90                         [drama]
# 5             NaN                         [drama]
# 6             NaN                         [drama]
# 7             NaN                         [drama]
# 8             120            [adventure, fantasy]
# 9             NaN                              []
#
#                        title_slug  average_rating  num_votes
# 0                      miss-jerry             5.3        210
# 1   the-corbett-fitzsimmons-fight             5.2        510
# 2                        bohemios             4.4         17
# 3     the-story-of-the-kelly-gang             6.0        886
# 4                the-prodigal-son             5.4         24
# 5              robbery-under-arms             4.3         25
# 6                          hamlet             2.9         27
# 7                     don-quijote             4.2         20
# 8  the-fairylogue-and-radio-plays             5.2         73
# 9                      faldgruben             4.4         17

# %% [markdown]
# # Importar Dados de Títulos do Netflix

# %%
df_netflix_titles = ps.read_csv('./data/netflix_titles.csv', sep=',', encoding='utf8', dtype=str)
df_netflix_titles.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# 12     s13    Movie                                       Je Suis Karl
# 13     s14    Movie                   Confessions of an Invisible Girl
# 14     s15  TV Show                    Crime Stories: India Detectives
# 15     s16  TV Show                                  Dear White People
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 18     s19    Movie                                          Intrusion
# 19     s20  TV Show                                             Jaguar
#
#                                          director  \
# 0                                 Kirsten Johnson
# 1                                             NaN
# 2                                 Julien Leclercq
# 3                                             NaN
# 4                                             NaN
# 5                                   Mike Flanagan
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# 8                                 Andy Devonshire
# 9                                  Theodore Melfi
# 10                                            NaN
# 11                              Kongkiat Komesiri
# 12                            Christian Schwochow
# 13                                  Bruno Garotti
# 14                                            NaN
# 15                                            NaN
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                            NaN
# 18                                     Adam Salky
# 19                                            NaN
#
#                                                  cast  \
# 0                                                 NaN
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 NaN
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 10                                                NaN
# 11  Sukollawat Kanarot, Sushar Manaying, Pavarit M...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 14                                                NaN
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...
# 16                                                NaN
# 17  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...
# 18  Freida Pinto, Logan Marshall-Green, Robert Joh...
# 19  Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...
#
#                                               country          date_added  \
# 0                                       United States  September 25, 2021
# 1                                        South Africa  September 24, 2021
# 2                                                 NaN  September 24, 2021
# 3                                                 NaN  September 24, 2021
# 4                                               India  September 24, 2021
# 5                                                 NaN  September 24, 2021
# 6                                                 NaN  September 24, 2021
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                      United Kingdom  September 24, 2021
# 9                                       United States  September 24, 2021
# 10                                                NaN  September 24, 2021
# 11                                                NaN  September 23, 2021
# 12                            Germany, Czech Republic  September 23, 2021
# 13                                                NaN  September 22, 2021
# 14                                                NaN  September 22, 2021
# 15                                      United States  September 22, 2021
# 16                                                NaN  September 22, 2021
# 17                                             Mexico  September 22, 2021
# 18                                                NaN  September 22, 2021
# 19                                                NaN  September 22, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
# 10         2021  TV-MA   1 Season
# 11         2021  TV-MA   1 Season
# 12         2021  TV-MA    127 min
# 13         2021  TV-PG     91 min
# 14         2021  TV-MA   1 Season
# 15         2021  TV-MA  4 Seasons
# 16         2020  TV-MA     67 min
# 17         2020  TV-MA  2 Seasons
# 18         2021  TV-14     94 min
# 19         2021  TV-MA   1 Season
#
#                                             listed_in  \
# 0                                       Documentaries
# 1     International TV Shows, TV Dramas, TV Mysteries
# 2   Crime TV Shows, International TV Shows, TV Act...
# 3                              Docuseries, Reality TV
# 4   International TV Shows, Romantic TV Shows, TV ...
# 5                  TV Dramas, TV Horror, TV Mysteries
# 6                            Children & Family Movies
# 7    Dramas, Independent Movies, International Movies
# 8                        British TV Shows, Reality TV
# 9                                    Comedies, Dramas
# 10  Crime TV Shows, Docuseries, International TV S...
# 11  Crime TV Shows, International TV Shows, TV Act...
# 12                       Dramas, International Movies
# 13                 Children & Family Movies, Comedies
# 14       British TV Shows, Crime TV Shows, Docuseries
# 15                             TV Comedies, TV Dramas
# 16                Documentaries, International Movies
# 17  Crime TV Shows, Spanish-Language TV Shows, TV ...
# 18                                          Thrillers
# 19  International TV Shows, Spanish-Language TV Sh...
#
#                                           description
# 0   As her father nears the end of his life, filmm...
# 1   After crossing paths at a party, a Cape Town t...
# 2   To protect his family from a powerful drug lor...
# 3   Feuds, flirtations and toilet talk go down amo...
# 4   In a city of coaching centers known to train I...
# 5   The arrival of a charismatic young priest brin...
# 6   Equestria's divided. But a bright-eyed hero be...
# 7   On a photo shoot in Ghana, an American model s...
# 8   A talented batch of amateur bakers face off in...
# 9   A woman adjusting to life after a loss contend...
# 10  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 11  Struggling to earn a living in Bangkok, a man ...
# 12  After most of her family is murdered in a terr...
# 13  When the clever but socially-awkward Tetê join...
# 14  Cameras following Bengaluru police on the job ...
# 15  Students of color navigate the daily slights a...
# 16  Declassified documents reveal the post-WWII li...
# 17  Strangers Diego and Isabel flee their home in ...
# 18  After a deadly home invasion at a couple’s new...
# 19  In the 1960s, a Holocaust survivor joins a gro...

# %% [markdown]
# ## Criar slug do título

# %%
df_netflix_titles['title_slug'] = df_netflix_titles['title'].fillna('').apply(lambda x: slugify(str(x)))
df_netflix_titles.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#   release_year rating   duration  \
# 0         2020  PG-13     90 min
# 1         2021  TV-MA  2 Seasons
# 2         2021  TV-MA   1 Season
# 3         2021  TV-MA   1 Season
# 4         2021  TV-MA  2 Seasons
# 5         2021  TV-MA   1 Season
# 6         2021     PG     91 min
# 7         1993  TV-MA    125 min
# 8         2021  TV-14  9 Seasons
# 9         2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...
#
#                         title_slug
# 0             dick-johnson-is-dead
# 1                      blood-water
# 2                        ganglands
# 3            jailbirds-new-orleans
# 4                     kota-factory
# 5                    midnight-mass
# 6  my-little-pony-a-new-generation
# 7                          sankofa
# 8    the-great-british-baking-show
# 9                     the-starling

# %%
types = df_netflix_titles['type'].unique()
types
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# ## Normalizar tipo

# %%
def normalize_netflix_type(value):
    if value == 'Movie':
        return 'movie'
    elif value == 'TV Show':
        return 'tvseries'
    else:
        return None

# %%
df_netflix_titles['type'] = df_netflix_titles['type'].apply(lambda x: normalize_netflix_type(x))
df_netflix_titles.head(10)
# Out:
#   show_id      type                             title  \
# 0      s1     movie              Dick Johnson Is Dead
# 1      s2  tvseries                     Blood & Water
# 2      s3  tvseries                         Ganglands
# 3      s4  tvseries             Jailbirds New Orleans
# 4      s5  tvseries                      Kota Factory
# 5      s6  tvseries                     Midnight Mass
# 6      s7     movie  My Little Pony: A New Generation
# 7      s8     movie                           Sankofa
# 8      s9  tvseries     The Great British Baking Show
# 9     s10     movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#   release_year rating   duration  \
# 0         2020  PG-13     90 min
# 1         2021  TV-MA  2 Seasons
# 2         2021  TV-MA   1 Season
# 3         2021  TV-MA   1 Season
# 4         2021  TV-MA  2 Seasons
# 5         2021  TV-MA   1 Season
# 6         2021     PG     91 min
# 7         1993  TV-MA    125 min
# 8         2021  TV-14  9 Seasons
# 9         2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...
#
#                         title_slug
# 0             dick-johnson-is-dead
# 1                      blood-water
# 2                        ganglands
# 3            jailbirds-new-orleans
# 4                     kota-factory
# 5                    midnight-mass
# 6  my-little-pony-a-new-generation
# 7                          sankofa
# 8    the-great-british-baking-show
# 9                     the-starling

# %% [markdown]
# ## Normalizar país

# %%
df_netflix_titles['country'] = df_netflix_titles['country'].fillna('').str.split(',')

# %%
df_netflix_titles.head(10)
# Out:
#   show_id      type                             title  \
# 0      s1     movie              Dick Johnson Is Dead
# 1      s2  tvseries                     Blood & Water
# 2      s3  tvseries                         Ganglands
# 3      s4  tvseries             Jailbirds New Orleans
# 4      s5  tvseries                      Kota Factory
# 5      s6  tvseries                     Midnight Mass
# 6      s7     movie  My Little Pony: A New Generation
# 7      s8     movie                           Sankofa
# 8      s9  tvseries     The Great British Baking Show
# 9     s10     movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                    [United States]  September 25, 2021
# 1                                     [South Africa]  September 24, 2021
# 2                                                 []  September 24, 2021
# 3                                                 []  September 24, 2021
# 4                                            [India]  September 24, 2021
# 5                                                 []  September 24, 2021
# 6                                                 []  September 24, 2021
# 7  [United States,  Ghana,  Burkina Faso,  United...  September 24, 2021
# 8                                   [United Kingdom]  September 24, 2021
# 9                                    [United States]  September 24, 2021
#
#   release_year rating   duration  \
# 0         2020  PG-13     90 min
# 1         2021  TV-MA  2 Seasons
# 2         2021  TV-MA   1 Season
# 3         2021  TV-MA   1 Season
# 4         2021  TV-MA  2 Seasons
# 5         2021  TV-MA   1 Season
# 6         2021     PG     91 min
# 7         1993  TV-MA    125 min
# 8         2021  TV-14  9 Seasons
# 9         2021  PG-13    104 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...
# 9  A woman adjusting to life after a loss contend...
#
#                         title_slug
# 0             dick-johnson-is-dead
# 1                      blood-water
# 2                        ganglands
# 3            jailbirds-new-orleans
# 4                     kota-factory
# 5                    midnight-mass
# 6  my-little-pony-a-new-generation
# 7                          sankofa
# 8    the-great-british-baking-show
# 9                     the-starling

# %% [markdown]
# # Combinando Dados do IMDB com Dados da Netflix

# %% [markdown]
# ## Separando Filmes e Séries do IMDB

# %%
df_imdb_movies = df_imdb[df_imdb['type'] == 'movie']
df_imdb_series = df_imdb[df_imdb['type'] == 'tvseries']

# %% [markdown]
# ## Combinando Filmes

# %%
df_movies = ps.merge(left=df_netflix_titles, right=df_imdb_movies, how='inner', on=['title_slug', 'type'])
df_movies.head(10)
# Out:
#   show_id   type                                         title  \
# 0      s1  movie                          Dick Johnson Is Dead
# 1      s7  movie              My Little Pony: A New Generation
# 2      s8  movie                                       Sankofa
# 3      s8  movie                                       Sankofa
# 4     s10  movie                                  The Starling
# 5     s13  movie                                  Je Suis Karl
# 6     s14  movie              Confessions of an Invisible Girl
# 7     s19  movie                                     Intrusion
# 8     s24  movie  Go! Go! Cory Carson: Chrissy Takes the Wheel
# 9     s25  movie                                         Jeans
#
#                         director  \
# 0                Kirsten Johnson
# 1  Robert Cullen, José Luis Ucha
# 2                   Haile Gerima
# 3                   Haile Gerima
# 4                 Theodore Melfi
# 5            Christian Schwochow
# 6                  Bruno Garotti
# 7                     Adam Salky
# 8        Alex Woo, Stanley Moore
# 9                     S. Shankar
#
#                                                 cast  \
# 0                                                NaN
# 1  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 4  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 5  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 6  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 7  Freida Pinto, Logan Marshall-Green, Robert Joh...
# 8  Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...
# 9  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                              country          date_added  \
# 0                                    [United States]  September 25, 2021
# 1                                                 []  September 24, 2021
# 2  [United States,  Ghana,  Burkina Faso,  United...  September 24, 2021
# 3  [United States,  Ghana,  Burkina Faso,  United...  September 24, 2021
# 4                                    [United States]  September 24, 2021
# 5                         [Germany,  Czech Republic]  September 23, 2021
# 6                                                 []  September 22, 2021
# 7                                                 []  September 22, 2021
# 8                                                 []  September 21, 2021
# 9                                            [India]  September 21, 2021
#
#   release_year rating duration  ...     imdb_id  \
# 0         2020  PG-13   90 min  ...  tt11394180
# 1         2021     PG   91 min  ...  tt10101702
# 2         1993  TV-MA  125 min  ...   tt0108041
# 3         1993  TV-MA  125 min  ...   tt4600776
# 4         2021  PG-13  104 min  ...   tt5164438
# 5         2021  TV-MA  127 min  ...   tt9205538
# 6         2021  TV-PG   91 min  ...  tt15204288
# 7         2021  TV-14   94 min  ...   tt5563324
# 8         2021   TV-Y   61 min  ...  tt15296598
# 9         1998  TV-14  166 min  ...   tt0151121
#
#                                   primary_title  \
# 0                          Dick Johnson Is Dead
# 1              My Little Pony: A New Generation
# 2                                       Sankofa
# 3                                       Sankofa
# 4                                  The Starling
# 5                                  Je Suis Karl
# 6              Confessions of an Invisible Girl
# 7                                     Intrusion
# 8  Go! Go! Cory Carson: Chrissy Takes the Wheel
# 9                                         Jeans
#
#                                  original_title is_adult start_year end_year  \
# 0                          Dick Johnson Is Dead     True     2020.0      NaN
# 1              My Little Pony: A New Generation     True     2021.0      NaN
# 2                                       Sankofa     True     1993.0      NaN
# 3                                       Sankofa     True     2014.0      NaN
# 4                                  The Starling     True     2021.0      NaN
# 5                                  Je suis Karl     True     2021.0      NaN
# 6             Confissões de uma Garota Excluída     True     2021.0      NaN
# 7                                     Intrusion     True     2021.0      NaN
# 8  Go! Go! Cory Carson: Chrissy Takes the Wheel     True     2021.0      NaN
# 9                                         Jeans     True     1998.0      NaN
#
#    runtime_minutes                           genres  average_rating num_votes
# 0               89  [biography, documentary, drama]             7.4      7226
# 1               90   [adventure, animation, comedy]             6.8      4505
# 2              125                          [drama]             7.0       805
# 3               77                         [sci-fi]             6.9        10
# 4              102                  [comedy, drama]             6.4     15273
# 5              126       [drama, romance, thriller]             5.5      1560
# 6               91                  [comedy, drama]             5.3      1377
# 7               92         [action, drama, mystery]             5.3     21058
# 8               60              [animation, family]             6.7        58
# 9              175         [comedy, drama, romance]             6.4      3959
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Limpando Colunas

# %%
df_movies.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'title_slug', 'imdb_id', 'primary_title', 'original_title', 'is_adult',
#        'start_year', 'end_year', 'runtime_minutes', 'genres', 'average_rating',
#        'num_votes'],
#       dtype='object')

# %%
df_movies.drop(columns=['show_id', 'cast', 'rating', 'description', 'is_adult'], inplace=True)

# %%
df_movies.head(4)
# Out:
#     type                             title                       director  \
# 0  movie              Dick Johnson Is Dead                Kirsten Johnson
# 1  movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 2  movie                           Sankofa                   Haile Gerima
# 3  movie                           Sankofa                   Haile Gerima
#
#                                              country          date_added  \
# 0                                    [United States]  September 25, 2021
# 1                                                 []  September 24, 2021
# 2  [United States,  Ghana,  Burkina Faso,  United...  September 24, 2021
# 3  [United States,  Ghana,  Burkina Faso,  United...  September 24, 2021
#
#   release_year duration                                         listed_in  \
# 0         2020   90 min                                     Documentaries
# 1         2021   91 min                          Children & Family Movies
# 2         1993  125 min  Dramas, Independent Movies, International Movies
# 3         1993  125 min  Dramas, Independent Movies, International Movies
#
#                         title_slug     imdb_id  \
# 0             dick-johnson-is-dead  tt11394180
# 1  my-little-pony-a-new-generation  tt10101702
# 2                          sankofa   tt0108041
# 3                          sankofa   tt4600776
#
#                       primary_title                    original_title  \
# 0              Dick Johnson Is Dead              Dick Johnson Is Dead
# 1  My Little Pony: A New Generation  My Little Pony: A New Generation
# 2                           Sankofa                           Sankofa
# 3                           Sankofa                           Sankofa
#
#    start_year  end_year runtime_minutes                           genres  \
# 0      2020.0       NaN              89  [biography, documentary, drama]
# 1      2021.0       NaN              90   [adventure, animation, comedy]
# 2      1993.0       NaN             125                          [drama]
# 3      2014.0       NaN              77                         [sci-fi]
#
#    average_rating  num_votes
# 0             7.4       7226
# 1             6.8       4505
# 2             7.0        805
# 3             6.9         10

# %% [markdown]
# ## Combinando Séries

# %%
df_series = ps.merge(left=df_netflix_titles, right=df_imdb_series, how='inner', on=['title_slug', 'type'])
df_series.head(10)
# Out:
#   show_id      type                            title           director  \
# 0      s2  tvseries                    Blood & Water                NaN
# 1      s3  tvseries                        Ganglands    Julien Leclercq
# 2      s4  tvseries            Jailbirds New Orleans                NaN
# 3      s5  tvseries                     Kota Factory                NaN
# 4      s9  tvseries    The Great British Baking Show    Andy Devonshire
# 5     s12  tvseries                 Bangkok Breaking  Kongkiat Komesiri
# 6     s15  tvseries  Crime Stories: India Detectives                NaN
# 7     s16  tvseries                Dear White People                NaN
# 8     s20  tvseries                           Jaguar                NaN
# 9     s26  tvseries             Love on the Spectrum                NaN
#
#                                                 cast           country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    [South Africa]
# 1  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...                []
# 2                                                NaN                []
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...           [India]
# 4  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  [United Kingdom]
# 5  Sukollawat Kanarot, Sushar Manaying, Pavarit M...                []
# 6                                                NaN                []
# 7  Logan Browning, Brandon P. Bell, DeRon Horton,...   [United States]
# 8  Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...                []
# 9                                   Brooke Satchwell       [Australia]
#
#            date_added release_year rating   duration  ...     imdb_id  \
# 0  September 24, 2021         2021  TV-MA  2 Seasons  ...   tt9839146
# 1  September 24, 2021         2021  TV-MA   1 Season  ...  tt13278100
# 2  September 24, 2021         2021  TV-MA   1 Season  ...  tt15320436
# 3  September 24, 2021         2021  TV-MA  2 Seasons  ...   tt9432978
# 4  September 24, 2021         2021  TV-14  9 Seasons  ...   tt1877368
# 5  September 23, 2021         2021  TV-MA   1 Season  ...  tt14202282
# 6  September 22, 2021         2021  TV-MA   1 Season  ...  tt14178956
# 7  September 22, 2021         2021  TV-MA  4 Seasons  ...   tt5707802
# 8  September 22, 2021         2021  TV-MA   1 Season  ...  tt11698590
# 9  September 21, 2021         2021  TV-14  2 Seasons  ...  tt11904786
#
#                      primary_title                   original_title is_adult  \
# 0                    Blood & Water                    Blood & Water     True
# 1                        Ganglands                        Braqueurs     True
# 2            Jailbirds New Orleans            Jailbirds New Orleans     True
# 3                     Kota Factory                     Kota Factory     True
# 4    The Great British Baking Show       The Great British Bake Off     True
# 5                 Bangkok Breaking                 Bangkok Breaking     True
# 6  Crime Stories: India Detectives  Crime Stories: India Detectives     True
# 7                Dear White People                Dear White People     True
# 8                           Jaguar                           Jaguar     True
# 9             Love on the Spectrum             Love on the Spectrum     True
#
#   start_year end_year  runtime_minutes                              genres  \
# 0     2020.0      NaN               53                    [drama, mystery]
# 1     2021.0      NaN               44              [action, crime, drama]
# 2     2021.0      NaN              NaN           [documentary, reality-tv]
# 3     2019.0   2021.0               40                     [comedy, drama]
# 4     2010.0      NaN               60             [game-show, reality-tv]
# 5     2021.0   2021.0               60              [action, crime, drama]
# 6     2021.0      NaN               47       [crime, documentary, mystery]
# 7     2017.0   2021.0               30                     [comedy, drama]
# 8     2021.0   2021.0               50            [action, drama, history]
# 9     2019.0   2021.0               45  [documentary, reality-tv, romance]
#
#    average_rating num_votes
# 0             6.7      4279
# 1             7.2      4520
# 2             6.6       301
# 3             9.0     80331
# 4             8.6     12830
# 5             5.9       364
# 6             7.0      1173
# 7             6.4     26406
# 8             5.9      2219
# 9             8.6      7543
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Limpando Colunas

# %%
df_series.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'title_slug', 'imdb_id', 'primary_title', 'original_title', 'is_adult',
#        'start_year', 'end_year', 'runtime_minutes', 'genres', 'average_rating',
#        'num_votes'],
#       dtype='object')

# %%
df_series.drop(columns=['show_id', 'cast', 'rating', 'description', 'is_adult'], inplace=True)

# %%
df_movies.head(4)
